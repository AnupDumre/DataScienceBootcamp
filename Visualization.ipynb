# %% [markdown]
# ## This is the portion of Pre-Processing.

# %%
import pandas as pd
import numpy as np

# %%
titanic = pd.read_csv('titanic.csv')
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
titanic.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
# Removing the 'Name' column from the Titanic dataset is a reasonable decision as names are unlikely to directly influence a person's survival. Names are usually unique identifiers and do not inherently offer predictive value for survival prediction. However, it's worth noting that certain titles within the name (e.g., "Mr.," "Mrs.," "Miss," etc.) might provide some indication of social status or gender, which could be relevant for survival prediction. Therefore, it is important to perform a thorough data analysis and consider potential implications on the model's performance before proceeding with this deletion. Always validate the decision with data analysis and model evaluation to ensure it doesn't significantly affect the predictive capabilities of the model.

del titanic['Name']
titanic.head()
# Out:
#    PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch  \
# 0            1         0       3    male  22.0      1      0
# 1            2         1       1  female  38.0      1      0
# 2            3         1       3  female  26.0      0      0
# 3            4         1       1  female  35.0      1      0
# 4            5         0       3    male  35.0      0      0
#
#              Ticket     Fare Cabin Embarked
# 0         A/5 21171   7.2500   NaN        S
# 1          PC 17599  71.2833   C85        C
# 2  STON/O2. 3101282   7.9250   NaN        S
# 3            113803  53.1000  C123        S
# 4            373450   8.0500   NaN        S

# %%
#'Fare' column can never decide survival of a person, hence we can safely delete it

del titanic['Fare']
titanic.head()
# Out:
#    PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch  \
# 0            1         0       3    male  22.0      1      0
# 1            2         1       1  female  38.0      1      0
# 2            3         1       3  female  26.0      0      0
# 3            4         1       1  female  35.0      1      0
# 4            5         0       3    male  35.0      0      0
#
#              Ticket Cabin Embarked
# 0         A/5 21171   NaN        S
# 1          PC 17599   C85        C
# 2  STON/O2. 3101282   NaN        S
# 3            113803  C123        S
# 4            373450   NaN        S

# %%
del titanic['Cabin']
titanic.head()
# Out:
#    PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch  \
# 0            1         0       3    male  22.0      1      0
# 1            2         1       1  female  38.0      1      0
# 2            3         1       3  female  26.0      0      0
# 3            4         1       1  female  35.0      1      0
# 4            5         0       3    male  35.0      0      0
#
#              Ticket Embarked
# 0         A/5 21171        S
# 1          PC 17599        C
# 2  STON/O2. 3101282        S
# 3            113803        S
# 4            373450        S

# %%
#changing values for "Male, Female" string values to numeric values, i.e, male = 1 and female = 0
def getNumber(str):
        if str == "male":
                return 1
        else:
                return 0
titanic["Gender"]=titanic['Sex'].apply(getNumber)
#We have created new column name "Gender" and filling it with values 1,0 based on the values of sex column
titanic.head()
# Out:
#    PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch  \
# 0            1         0       3    male  22.0      1      0
# 1            2         1       1  female  38.0      1      0
# 2            3         1       3  female  26.0      0      0
# 3            4         1       1  female  35.0      1      0
# 4            5         0       3    male  35.0      0      0
#
#              Ticket Embarked  Gender
# 0         A/5 21171        S       1
# 1          PC 17599        C       0
# 2  STON/O2. 3101282        S       0
# 3            113803        S       0
# 4            373450        S       1

# %%
from sklearn.preprocessing import LabelEncoder
labelencoder = LabelEncoder()
titanic['Sex']= labelencoder.fit_transform(titanic['Sex'])
titanic.head()

#this code snippet converts the categorical 'Sex' column in the 'titanic' DataFrame (which contains string values like 'male' and 'female') into numeric values (typically 0 for one category and 1 for the other) using the LabelEncoder from scikit-learn. This numeric encoding allows machine learning algorithms to work with categorical data effectively.
# Out:
#    PassengerId  Survived  Pclass  Sex   Age  SibSp  Parch            Ticket  \
# 0            1         0       3    1  22.0      1      0         A/5 21171
# 1            2         1       1    0  38.0      1      0          PC 17599
# 2            3         1       3    0  26.0      0      0  STON/O2. 3101282
# 3            4         1       1    0  35.0      1      0            113803
# 4            5         0       3    1  35.0      0      0            373450
#
#   Embarked  Gender
# 0        S       1
# 1        C       0
# 2        S       0
# 3        S       0
# 4        S       1

# %% [markdown]
# ###  LabelEncoder uses library so it converts string directly to the boolen.

# %%
titanic.isnull().sum() 
#checking for null values in the dataset and summing them up column wise to get the total number of null values in each column
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Embarked         2
# Gender           0
# dtype: int64

# %%
#Fill the missing age of the survived one with the mean age of the survival people and non survive age with non survival age ko mean

mean = titanic[titanic.Survived == 1].Age.mean()
mean
# Out:
# 28.343689655172415

# %%
death = titanic[titanic.Survived == 0].Age.mean()
death
# Out:
# 30.62617924528302

# %%
# Fill the missing values in the 'age' column of the 'titanic' DataFrame with the 'mean age' of the passengers who survived.
titanic['age'] =np.where(pd.isnull(titanic.Age) & titanic["Survived"]==1 ,mean, titanic['Age'])
titanic
# Out:
#      PassengerId  Survived  Pclass  Sex   Age  SibSp  Parch            Ticket  \
# 0              1         0       3    1  22.0      1      0         A/5 21171
# 1              2         1       1    0  38.0      1      0          PC 17599
# 2              3         1       3    0  26.0      0      0  STON/O2. 3101282
# 3              4         1       1    0  35.0      1      0            113803
# 4              5         0       3    1  35.0      0      0            373450
# ..           ...       ...     ...  ...   ...    ...    ...               ...
# 886          887         0       2    1  27.0      0      0            211536
# 887          888         1       1    0  19.0      0      0            112053
# 888          889         0       3    0   NaN      1      2        W./C. 6607
# 889          890         1       1    1  26.0      0      0            111369
# 890          891         0       3    1  32.0      0      0            370376
#
#     Embarked  Gender   age
# ...

# %%
titanic.age.fillna(death,inplace=True) # inplace le chai jun column herira ho tei ma operate garne
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  Sex   Age  SibSp  Parch            Ticket  \
# 0            1         0       3    1  22.0      1      0         A/5 21171
# 1            2         1       1    0  38.0      1      0          PC 17599
# 2            3         1       3    0  26.0      0      0  STON/O2. 3101282
# 3            4         1       1    0  35.0      1      0            113803
# 4            5         0       3    1  35.0      0      0            373450
#
#   Embarked  Gender   age
# 0        S       1  22.0
# 1        C       0  38.0
# 2        S       0  26.0
# 3        S       0  35.0
# 4        S       1  35.0

# %%
titanic.age.fillna(death,inplace=True) # inplace le chai jun column herira ho tei ma operate garne
titanic.tail()
# Out:
#      PassengerId  Survived  Pclass  Sex   Age  SibSp  Parch      Ticket  \
# 886          887         0       2    1  27.0      0      0      211536
# 887          888         1       1    0  19.0      0      0      112053
# 888          889         0       3    0   NaN      1      2  W./C. 6607
# 889          890         1       1    1  26.0      0      0      111369
# 890          891         0       3    1  32.0      0      0      370376
#
#     Embarked  Gender        age
# 886        S       1  27.000000
# 887        S       0  19.000000
# 888        S       0  30.626179
# 889        C       1  26.000000
# 890        Q       1  32.000000

# %%
# now you can see the Age has 177 null but that is replace at 'age' all null value is overcomed
titanic.isnull().sum()
# After filling the missing values, check for the total number of null values in the DataFrame.
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Embarked         2
# Gender           0
# age              0
# dtype: int64

# %%
#To check whether the Embarked will affect the survival of people or not

survivedQ = titanic[titanic.Embarked == 'Q'][titanic.Survived == 1].shape[0]
survivedS = titanic[titanic.Embarked == 'S'][titanic.Survived == 1].shape[0]
survivedC = titanic[titanic.Embarked == 'C'][titanic.Survived == 1].shape[0]
print(survivedQ)
print(survivedS)
print(survivedC)
# Out:
# 30
# 217
# 93
# C:\Users\anupa\AppData\Local\Temp\ipykernel_8868\4048908882.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   survivedQ = titanic[titanic.Embarked == 'Q'][titanic.Survived == 1].shape[0]
# C:\Users\anupa\AppData\Local\Temp\ipykernel_8868\4048908882.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   survivedS = titanic[titanic.Embarked == 'S'][titanic.Survived == 1].shape[0]
# C:\Users\anupa\AppData\Local\Temp\ipykernel_8868\4048908882.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   survivedC = titanic[titanic.Embarked == 'C'][titanic.Survived == 1].shape[0]

# %% [markdown]
# #### The UserWarnings occur because the boolean indexing with multiple conditions is not performed correctly. To fix this, you can use the 'loc' method to perform the boolean indexing with multiple conditions.

# %%
# Count the number of survivors for each port of embarkation
survivedQ = titanic.loc[(titanic['Embarked'] == 'Q') & (titanic['Survived'] == 1)].shape[0]
survivedS = titanic.loc[(titanic['Embarked'] == 'S') & (titanic['Survived'] == 1)].shape[0]
survivedC = titanic.loc[(titanic['Embarked'] == 'C') & (titanic['Survived'] == 1)].shape[0]

# Print the results
print(survivedQ)  # Number of survivors from Queenstown (Embarked Q)
print(survivedS)  # Number of survivors from Southampton (Embarked S)
print(survivedC)  # Number of survivors from Cherbourg (Embarked C)
# Out:
# 30
# 217
# 93

# %%
# Drop rows with missing values (NaN) from the 'titanic' DataFrame to ensure no missing data remains.

titanic.dropna(inplace=True) #Drop the entire row if it has a null value in any row
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  Sex   Age  SibSp  Parch            Ticket  \
# 0            1         0       3    1  22.0      1      0         A/5 21171
# 1            2         1       1    0  38.0      1      0          PC 17599
# 2            3         1       3    0  26.0      0      0  STON/O2. 3101282
# 3            4         1       1    0  35.0      1      0            113803
# 4            5         0       3    1  35.0      0      0            373450
#
#   Embarked  Gender   age
# 0        S       1  22.0
# 1        C       0  38.0
# 2        S       0  26.0
# 3        S       0  35.0
# 4        S       1  35.0

# %%
titanic.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Embarked       0
# Gender         0
# age            0
# dtype: int64

# %%
labelencoder = LabelEncoder()
titanic['Embarked'] = labelencoder.fit_transform(titanic['Embarked'])
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  Sex   Age  SibSp  Parch            Ticket  \
# 0            1         0       3    1  22.0      1      0         A/5 21171
# 1            2         1       1    0  38.0      1      0          PC 17599
# 2            3         1       3    0  26.0      0      0  STON/O2. 3101282
# 3            4         1       1    0  35.0      1      0            113803
# 4            5         0       3    1  35.0      0      0            373450
#
#    Embarked  Gender   age
# 0         2       1  22.0
# 1         0       0  38.0
# 2         2       0  26.0
# 3         2       0  35.0
# 4         2       1  35.0

# %%
titanic.tail()
# Out:
#      PassengerId  Survived  Pclass  Sex   Age  SibSp  Parch  Ticket  Embarked  \
# 885          886         0       3    0  39.0      0      5  382652         1
# 886          887         0       2    1  27.0      0      0  211536         2
# 887          888         1       1    0  19.0      0      0  112053         2
# 889          890         1       1    1  26.0      0      0  111369         0
# 890          891         0       3    1  32.0      0      0  370376         1
#
#      Gender   age
# 885       0  39.0
# 886       1  27.0
# 887       0  19.0
# 889       1  26.0
# 890       1  32.0

# %% [markdown]
# ## From here the portion of Visualization starts:

# %%
titanic
# Out:
#      PassengerId  Survived  Pclass  Sex   Age  SibSp  Parch            Ticket  \
# 0              1         0       3    1  22.0      1      0         A/5 21171
# 1              2         1       1    0  38.0      1      0          PC 17599
# 2              3         1       3    0  26.0      0      0  STON/O2. 3101282
# 3              4         1       1    0  35.0      1      0            113803
# 4              5         0       3    1  35.0      0      0            373450
# ..           ...       ...     ...  ...   ...    ...    ...               ...
# 885          886         0       3    0  39.0      0      5            382652
# 886          887         0       2    1  27.0      0      0            211536
# 887          888         1       1    0  19.0      0      0            112053
# 889          890         1       1    1  26.0      0      0            111369
# 890          891         0       3    1  32.0      0      0            370376
#
#      Embarked  Gender   age
# ...

# %%
import matplotlib.pyplot as plt
from matplotlib import style

# %%
# drawing a pie chart for the number of males and females

#summing up all the values of column gender with a condition for mle and similary for females
males = (titanic['Sex'] == 1).sum()

females = (titanic['Sex']==0).sum()

print(males)
# Out:
# 453

# %%
print(females)
# Out:
# 259

# %%
p = [males,females]
plt.pie(p,                            #giving array
        labels = ['Males','Females'], # coressponding giving Lables
        colors =['green', 'yellow'],  # corresponding colors
        explode = (0.15,0),            #how much the gap should be there between the pies
        startangle = 0)
plt.axis('equal')
plt.show()

# %%
MaleS = titanic[(titanic.Sex==1)&(titanic.Survived==1)].shape[0]
print(MaleS)

MaleNS = titanic[(titanic.Sex==1)&(titanic.Survived==0)].shape[0]
print(MaleNS)

FemaleS = titanic[(titanic.Sex==0)&(titanic.Survived==1)].shape[0]
print(MaleS)

FemaleNS = titanic[(titanic.Sex==0)&(titanic.Survived==0)].shape[0]
print(FemaleNS)
# Out:
# 93
# 360
# 93
# 64

# %%
p = [MaleS,MaleNS,FemaleS,FemaleNS]
plt.pie(p,                          #giving array
    labels = ['Male Survived','Male Not-Survived','Female Survived','Female Not-Survived'],     #correspondingly giving lables
    colors=['green','red','blue','yellow'],      # corresponding colors
    explode = (0.015,0.015,0.015,0.015),             #how much the gap should be there between the pies
    counterclock=False,
    autopct='%.2f%%',
    startangle= 0)
plt.axis('equal')
plt.show()

# %% [markdown]
# #
# ## Using 'seaborn'
# #

# %%
# draw a bar plot for SibSp vs Survival

import seaborn as sns
sns.barplot(x="SibSp", y="Survived", data=titanic)
# Out:
# <Axes: xlabel='SibSp', ylabel='Survived'>

# %%
# I will be printing indicisual percent values for all of these
print("Percentage of SibSp = 0 who survived: ", titanic["Survived"][titanic["SibSp"]==0].value_counts(normalize=True)[1]*100)
print("Percentage of SibSp = 1 who survived: ", titanic["Survived"][titanic["SibSp"]==1].value_counts(normalize=True)[1]*100)
print("Percentage of SibSp = 2 who survived: ", titanic["Survived"][titanic["SibSp"]==2].value_counts(normalize=True)[1]*100)
print("Percentage of SibSp = 3 who survived: ", titanic["Survived"][titanic["SibSp"]==3].value_counts(normalize=True)[1]*100)
# Out:
# Percentage of SibSp = 0 who survived:  36.88699360341152
# Percentage of SibSp = 1 who survived:  53.00546448087432
# Percentage of SibSp = 2 who survived:  44.0
# Percentage of SibSp = 3 who survived:  33.33333333333333

# %%
titanic.groupby('Embarked').Age.mean()
# Out:
# Embarked
# 0    30.814769
# 1    28.089286
# 2    29.445397
# Name: Age, dtype: float64

# %%
titanic["Survived"][titanic["SibSp"] == 0].value_counts(normalize=True)[1] * 100
# Out:
# 36.88699360341152

# %%
titanic['Age'].hist(bins = 70)
# Out:
# <Axes: >

# %%
sns.barplot( x = "Embarked", y ="Survived", hue="Pclass", data = titanic)
plt.show()

# %%
fig, ax = plt.subplots(1, 2, figsize=(18, 10))

titanic[titanic["Survived"] == 0]["Age"].plot.hist(ax=ax[0], bins=20, edgecolor="black", color="blue")
ax[0].set_title("Unsurvived")
domain_1 = list(range(0, 85, 5))
ax[0].set_xticks(domain_1)

titanic[titanic["Survived"] == 1]["Age"].plot.hist(ax=ax[1], bins=20, edgecolor="black", color="green")
ax[1].set_title("Survived")
domain_2 = list(range(0, 85, 5))
ax[1].set_xticks(domain_2)

plt.show()

# %%
titanic.groupby('Embarked').Age.mean()
# Out:
# Embarked
# 0    30.814769
# 1    28.089286
# 2    29.445397
# Name: Age, dtype: float64

# %% [markdown]
# # Classification Algorithm

# %% [markdown]
# ### Logistic Algorithm

# %%
del titanic['Ticket']

# %%
X = titanic.drop('Survived', axis =1)
y = titanic['Survived']

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression


# Perform the train-test split once
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)

# %%
logmodel = LogisticRegression()
logmodel.fit(x_train, y_train)
predictions = logmodel.predict(x_test)
# Out:
# C:\Python311\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
acc_log = round(logmodel.score(x_train , y_train)*100,2)
acc_log
# Out:
# 80.52

# %%
acc_log = round(logmodel.score(x_test,y_test) * 100 , 2)
acc_log
# Out:
# 77.57

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      0.81      0.81       128
#            1       0.72      0.72      0.72        86
#
#     accuracy                           0.78       214
#    macro avg       0.77      0.77      0.77       214
# weighted avg       0.78      0.78      0.78       214

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(y_test, predictions)
# Out:
# array([[104,  24],
#        [ 24,  62]], dtype=int64)

# %% [markdown]
# ## TP FP
# ## FN TN

# %% [markdown]
# # --

# %% [markdown]
# # Support Vector Machine

# %%
from sklearn.svm import SVC
svc = SVC()
svc.fit(x_train, y_train)
y_pred = svc.predict(x_test)
train_acc_svc = round(svc.score(x_train, y_train)* 100 , 2)
acc_svc = round(svc.score(x_test, y_test) * 100 , 2)
print(train_acc_svc, acc_svc)
# Out:
# 59.44 59.81

# %% [markdown]
# # K Nearest Neighbours Algorithm

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors = 3)
knn.fit(x_train, y_train)
y_ored = knn.predict(x_test)
train_acc_knn = round(knn.score(x_train, y_train)*100 ,2)
acc_knn = round(knn.score(x_test, y_test)*100,2)
print(train_acc_knn, acc_knn)
# Out:
# 76.51 50.0

# %% [markdown]
# # Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier
decision_tree = DecisionTreeClassifier()
decision_tree.fit(x_train, y_train)
y_pred = decision_tree.predict(x_test)
acc_decision_tree = round(decision_tree.score(x_test, y_test)*100, 2)
acc_decision_tree
# Out:
# 74.77
